# %% [markdown]
# what the difference between hardware and software
# hardware:touchable or tangabile physically it appears
# examples:cpu,mouse,monitor,keyboard,printers
# software:it tell to hardware what to do
# digital
# examples:
# web pages,apps,etc
